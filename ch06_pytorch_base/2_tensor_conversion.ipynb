# %%
import torch
import numpy as np

# %%
tensor1 = torch.tensor([1, 2, 3])
print(tensor1)
print(tensor1.dtype)
# Out:
# tensor([1, 2, 3])
# torch.int64

# %%
tensor1 = tensor1.type(torch.float64)
print(tensor1.dtype)
# Out:
# torch.float64

# %%
tensor1 = tensor1.half()
print(tensor1.dtype)
# Out:
# torch.float16

# %%
print(tensor1)
# Out:
# tensor([1., 2., 3.], dtype=torch.float16)

# %%
tensor1 = tensor1.to(torch.complex64)
print(tensor1,tensor1.dtype)
# Out:
# tensor([1.+0.j, 2.+0.j, 3.+0.j]) torch.complex64

# %% [markdown]
# 6.4.2Tensor与ndarray转换

# %%
np.set_printoptions(precision=6)
torch.set_printoptions(precision=6)

#1. tensor → ndarray
tensor1 = torch.rand(3,2)
print(tensor1)
# Out:
# tensor([[0.268422, 0.636172],
#         [0.061928, 0.047677],
#         [0.788978, 0.839853]])

# %%
ndarray1 =tensor1.numpy()
print(ndarray1)
# Out:
# [[0.268422 0.636172]
#  [0.061928 0.047677]
#  [0.788978 0.839853]]

# %%
tensor1[:, 0] = 10
print(tensor1)
print(ndarray1)
# Out:
# tensor([[10.000000,  0.636172],
#         [10.000000,  0.047677],
#         [10.000000,  0.839853]])
# [[10.        0.636172]
#  [10.        0.047677]
#  [10.        0.839853]]

# %%
# 使用copy方法避免共享内存
ndarray2 = tensor1.numpy().copy()
print(ndarray2)
# Out:
# [[10.        0.636172]
#  [10.        0.047677]
#  [10.        0.839853]]

# %%
tensor1[:, 0] = 5
print(tensor1)
print(ndarray1)
print(ndarray2)
# Out:
# tensor([[5.000000, 0.636172],
#         [5.000000, 0.047677],
#         [5.000000, 0.839853]])
# [[5.       0.636172]
#  [5.       0.047677]
#  [5.       0.839853]]
# [[10.        0.636172]
#  [10.        0.047677]
#  [10.        0.839853]]

# %%
#2.ndarray → tensor
ndarray1 = np.random.randn(3,2)
tensor1 = torch.from_numpy(ndarray1)
print(tensor1)
print(ndarray1)
# Out:
# tensor([[-0.165407, -0.397431],
#         [-0.291761, -1.612272],
#         [ 1.228428, -0.744045]], dtype=torch.float64)
# [[-0.165407 -0.397431]
#  [-0.291761 -1.612272]
#  [ 1.228428 -0.744045]]

# %%
ndarray1[:,0] = 5
print(tensor1)
print(ndarray1)
# Out:
# tensor([[ 5.000000, -0.397431],
#         [ 5.000000, -1.612272],
#         [ 5.000000, -0.744045]], dtype=torch.float64)
# [[ 5.       -0.397431]
#  [ 5.       -1.612272]
#  [ 5.       -0.744045]]

# %%
#使用copy方法避免内存共享
tensor2 = torch.from_numpy(ndarray1.copy())
ndarray1[:,0] = 7
print(ndarray1)
print(tensor1)
print(tensor2)
# Out:
# [[ 7.       -0.397431]
#  [ 7.       -1.612272]
#  [ 7.       -0.744045]]
# tensor([[ 7.000000, -0.397431],
#         [ 7.000000, -1.612272],
#         [ 7.000000, -0.744045]], dtype=torch.float64)
# tensor([[ 5.000000, -0.397431],
#         [ 5.000000, -1.612272],
#         [ 5.000000, -0.744045]], dtype=torch.float64)

# %%
#使用tensor方法直接转换成Tensor
ndarray1 = np.random.randn(3,2)
tensor1 = torch.tensor(ndarray1)
print(tensor1)
print(ndarray1)
# Out:
# tensor([[ 1.044981, -0.662519],
#         [ 0.637965, -0.512655],
#         [ 0.637125, -0.084013]], dtype=torch.float64)
# [[ 1.044981 -0.662519]
#  [ 0.637965 -0.512655]
#  [ 0.637125 -0.084013]]

# %%
ndarray1[:,0] = 5
print(tensor1)
print(ndarray1)
# Out:
# tensor([[ 1.044981, -0.662519],
#         [ 0.637965, -0.512655],
#         [ 0.637125, -0.084013]], dtype=torch.float64)
# [[ 5.       -0.662519]
#  [ 5.       -0.512655]
#  [ 5.       -0.084013]]

# %%
#张量与标量转换
tensor1 = torch.tensor(10)
print(tensor1)
# Out:
# tensor(10)

# %%
print(tensor1.item())
# Out:
# 10

# %%
tensor1 = torch.tensor([[10]])
print(tensor1)
print(tensor1.item())
# Out:
# tensor([[10]])
# 10
