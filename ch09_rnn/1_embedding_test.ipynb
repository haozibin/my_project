# %%
import torch
import torch.nn as nn
import jieba
from IPython import embed
# Out:
# D:\dl_tutorial\.venv\Lib\site-packages\jieba\_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
text = "自然语言是由文字构成的，而语言的含义是由单词构成的。即单词是含义的最小单位。因此为了让计算机理解自然语言，首先要让它理解单词含义。"

# %%
# 1. 分词
orignal_words = jieba.lcut(text)
print(orignal_words)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 0.407 seconds.
# Prefix dict has been built successfully.
# ['自然语言', '是', '由', '文字', '构成', '的', '，', '而', '语言', '的', '含义', '是', '由', '单词', '构成', '的', '。', '即', '单词', '是', '含义', '的', '最小', '单位', '。', '因此', '为了', '让', '计算机', '理解', '自然语言', '，', '首先', '要', '让', '它', '理解', '单词', '含义', '。']

# %%
# 自定义一组停用词
stopwords = {"的","是","而","由","，","。"}

# %%
# 2. 过滤停用词和标点符号
words = [word for word in orignal_words if word not in stopwords]
print(words)
# Out:
# ['自然语言', '文字', '构成', '语言', '含义', '单词', '构成', '即', '单词', '含义', '最小', '单位', '因此', '为了', '让', '计算机', '理解', '自然语言', '首先', '要', '让', '它', '理解', '单词', '含义']

# %%
# 3. 构建词表（id2word）
id2word = list(set(words))
print(id2word)
# Out:
# ['单词', '计算机', '单位', '理解', '即', '含义', '构成', '首先', '让', '要', '语言', '自然语言', '为了', '它', '文字', '最小', '因此']

# %%
# 4. 构建字典，保存word到索引的映射(word2id)
word2id = dict()
for id, word in enumerate(id2word):
    word2id[word] = id
print(word2id)
# Out:
# {'单词': 0, '计算机': 1, '单位': 2, '理解': 3, '即': 4, '含义': 5, '构成': 6, '首先': 7, '让': 8, '要': 9, '语言': 10, '自然语言': 11, '为了': 12, '它': 13, '文字': 14, '最小': 15, '因此': 16}

# %%
# 5. 构建一个嵌入曾
embed = nn.Embedding(num_embeddings=len(id2word), embedding_dim=5)
print(embed)
# Out:
# Embedding(17, 5)

# %%
# 6. 前向传播，传入单词索引号，得到词向量
for id,word in enumerate(id2word):
    word_vec = embed(torch.tensor(id))
    print(f"{id:>2}:{word:8}\t{word_vec.detach().numpy()}")
# Out:
#  0:单词      	[ 0.326621    0.42069066 -0.97170126 -0.27164328  0.59877384]
#  1:计算机     	[-1.5854691   0.7413429  -1.273978   -1.6992825   0.15468149]
#  2:单位      	[ 0.6024519   0.5213413  -0.35778987 -3.1904922  -1.3246127 ]
#  3:理解      	[ 0.3454817  -0.7846463   1.222988    0.71636915  0.7874868 ]
#  4:即       	[-2.5134766  -0.5177895  -0.24628809 -1.271356   -0.10930114]
#  5:含义      	[ 0.17198297 -1.041866    0.996668   -2.310807    0.06585566]
#  6:构成      	[ 0.20464353 -0.50631344 -0.8603018  -0.45886654  0.9239384 ]
#  7:首先      	[ 0.13548848 -1.6376821  -0.08804984  0.14317147  1.0057153 ]
#  8:让       	[-0.1454465  -2.2151597  -0.04895923 -1.1118507  -0.2915137 ]
#  9:要       	[ 0.10778658 -0.6168626   0.31010947 -0.17779541  1.0031638 ]
# 10:语言      	[ 1.136733    0.05478695 -0.7213035  -0.70217705  1.0311979 ]
# 11:自然语言    	[-2.3573318  -1.9993432   0.46489075 -0.14888626 -0.31701377]
# 12:为了      	[-0.95915586 -0.85346526 -0.53594357 -0.36468074  1.3047047 ]
# 13:它       	[ 0.61496     0.71128374 -0.33077034  2.2991376  -1.4702088 ]
# 14:文字      	[ 0.850655   -3.1091146  -0.6279897   0.43048412  1.4296036 ]
# 15:最小      	[ 0.04752038 -0.33770344  0.2998095   0.52770007 -0.33778194]
# 16:因此      	[ 0.22230509 -0.16973208  0.2624859   0.12864824 -0.38642386]

# %%
nn.Embedding.from_pretrained()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 nn.Embedding.from_pretrained()
#
# TypeError: Embedding.from_pretrained() missing 1 required positional argument: 'embeddings'
