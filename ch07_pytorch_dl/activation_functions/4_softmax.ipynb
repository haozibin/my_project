# %%
import torch

# %%
x = torch.randn(3,5)
print(x)
# Out:
# tensor([[ 0.2553, -0.9848, -0.2314,  1.3843, -0.5061],
#         [ 1.3097, -0.0678, -1.1052,  0.5667, -0.6852],
#         [-0.4513,  0.4427, -0.5244,  1.6606,  1.4751]])

# %%
y = torch.softmax(x, dim=1)
print(y)
# Out:
# tensor([[0.1830, 0.0530, 0.1125, 0.5660, 0.0855],
#         [0.5120, 0.1291, 0.0458, 0.2435, 0.0696],
#         [0.0513, 0.1254, 0.0477, 0.4237, 0.3520]])
