# %%
import torch
import torch.nn as nn

# %%
x = torch.randint(1,10,(10,),dtype=torch.float32)

# %%
#定义一个Dropoutceng
dropout = nn.Dropout(p=0.5)

# %%
y = dropout(x)

# %%
print(x)
print(y)
# Out:
# tensor([4., 9., 8., 1., 4., 3., 8., 3., 8., 5.])
# tensor([ 0.,  0., 16.,  0.,  8.,  6.,  0.,  0., 16., 10.])
